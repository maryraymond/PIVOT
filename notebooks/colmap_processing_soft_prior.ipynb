# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

# %%
import sys
sys.path.append("/code/src/")

# %%
from colmap_processing import run_colmap_with_soft_priors, CameraMode

# %%
dataset = Path("/workspace/datasets/bench")
dataset_images_dir = dataset / "images"
colmap_dir = dataset / "PYCOLMAP_soft_prior"

# %%
run_colmap_with_soft_priors(dataset_images_dir=dataset_images_dir, colmap_dir=colmap_dir,
                            pos_var=[6, 6, 6], update_positions=True, cartesian_system=True,
                            camera_mode=CameraMode.PER_FOLDER, max_num_models=4)
