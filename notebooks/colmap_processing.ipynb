# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

# %%
import sys
sys.path.append("/code/src/")

# %%
from colmap_processing import run_colmap

# %%
dataset = Path("/workspace/datasets/bench")
dataset_images_dir = dataset / "images"
colmap_dir = dataset / "PYCOLMAP"
colmap_db = colmap_dir / "database.db"
colmap_out_dir = colmap_dir / "sparse"

# %%
run_colmap(dataset_images_dir=dataset_images_dir, colmap_dir=colmap_dir)
