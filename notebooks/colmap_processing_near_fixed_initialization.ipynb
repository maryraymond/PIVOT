# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

# %%
import sys
sys.path.append("/code/src/")

# %%
dataset = Path("/workspace/datasets/bench")
dataset_images_dir = dataset / "images"
colmap_dir = dataset / "PYCOLMAP_fixed_init"
camera_calibration = "/code/data/camera_calibration.json"

# %%
from colmap_processing import run_colmap_with_initialization

# %%
run_colmap_with_initialization(dataset_images_dir=dataset_images_dir, 
                               camera_calibration_file=camera_calibration, 
                               colmap_dir=colmap_dir)
